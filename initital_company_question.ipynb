# %%
import os

import django

os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'EarlyBird.settings.development')
os.environ['DJANGO_ALLOW_ASYNC_UNSAFE'] = 'true'
django.setup()
# from questionnaire.models import Question, QuestionDefaultAnswer
from django.db import transaction
# TODO translate vietnamize
INVESTMENT_PROFILE = 'investment_profile'
Project_PROFILE = 'projec_profile'


# from apps.questionnaire.models import QuestionClass, Question, QuestionDefaultAnswer

from apps.questionnaire.models import Question, QuestionDefaultAnswer
def structure_qs(qs_class, question_text, question_code, hint=None, related_to=None, ans1=None, ans2=None, ans3=None,
                 ans4=None,
                 ans5=None,
                 widget_type=''
                 ):
    return {
        'widget_type': widget_type if widget_type else 'single_choice' if ans1 else 'input_text',
        'question_class': qs_class,
        'question_text': question_text,
        'question_hint': hint,
        'question_code': question_code,
        'related_to': related_to,
        'ans1': ans1,
        'ans2': ans2,
        'ans3': ans3,
        'ans4': ans4,
        'ans5': ans5,
    }


investment_qs = [
    ### team info ...
    structure_qs(qs_class='team',
                 question_text='Why did you start this company? What excites you about it?',
                 related_to=Project_PROFILE,
                 question_code='project_motivation'
                 ),

    structure_qs(qs_class='team',
                 question_text='If co-founders, how did you meet?',
                 related_to=Project_PROFILE,
                 question_code='project_team_how_meet'
                 ),
    structure_qs(qs_class='team',
                 question_text='How many full-time employees are in the team? How many are developers/engineers? Where are they located? Office-based or working from home?',
                 related_to=Project_PROFILE,
                 question_code='project_employees'
                 ),
    structure_qs(qs_class='team',
                 question_text='What is the domain expertise of the team?',
                 related_to=Project_PROFILE,
                 question_code='project_team_domain'
                 ),
    structure_qs(qs_class='team',
                 question_text='Organizational chart.',
                 related_to=Project_PROFILE,
                 question_code='project_org_chart'
                 ),
    structure_qs(qs_class='team',
                 question_text='Current company beneficial owners above 10% KYC (we need due diligence team).',
                 related_to=Project_PROFILE,
                 question_code='project_beneficial_owners'
                 ),
    structure_qs(qs_class='team',
                 question_text='Tell us about your previous start-up and corporate experience.',
                 related_to=Project_PROFILE,
                 question_code='project_previous_exp'
                 ),

    structure_qs(qs_class='team',
                 question_text='Are you eligible to work in Vietnam? Do you hold an Vietnamese passport or Vietnamese working permit?',
                 related_to=Project_PROFILE,
                 question_code='project_vietnamese_permit'
                 ),

    structure_qs(qs_class='team',
                 question_text='Tell us about a time you most successfully hacked some system (non-computer) to your advantage.',
                 related_to=Project_PROFILE,
                 question_code='project_successfully'
                 ),

    structure_qs(qs_class='team',
                 question_text='Tell us about an interesting project, preferably outside of class or work, that two or more of you created together.',
                 related_to=Project_PROFILE,
                 question_code='project_interesting_created_project'
                 ),

    ### customer info ...
    structure_qs(qs_class='customers',
                 question_text='Who are your customers and/or users in more detail?',
                 related_to=Project_PROFILE,
                 question_code='project_customers'
                 ),
    structure_qs(qs_class='customers',
                 question_text='Explain how your proposition will alleviate specific customer pain-points.',
                 related_to=Project_PROFILE,
                 question_code='project_customer_alleviate'
                 ),
    structure_qs(qs_class='customers',
                 question_text='How will you acquire customers/users?',
                 related_to=Project_PROFILE,
                 question_code='project_acquire_customers'
                 ),
    structure_qs(qs_class='customers',
                 question_text='Who are your competitors, and who might become competitors?',
                 related_to=Project_PROFILE,
                 question_code='project_competitors'
                 ),

    structure_qs(qs_class='customers',
                 question_text='Who do you fear most?',
                 related_to=Project_PROFILE,
                 question_code='project_fear'
                 ),

    # idea information
    structure_qs(qs_class='idea',
                 question_text="How do you know people need what you're making?",
                 related_to=Project_PROFILE,
                 question_code='project_people_need'
                 ),
    structure_qs(qs_class='idea',
                 question_text="What's new about what you're making?",
                 related_to=Project_PROFILE,
                 question_code='project_what_is_new'
                 ),
    structure_qs(qs_class='idea',
                 question_text="What substitutes do your target personas resort to because it doesn't exist yet?",
                 related_to=Project_PROFILE,
                 question_code='project_replacement_for_customer'
                 ),
    structure_qs(qs_class='idea',
                 question_text='Is this idea a derivative of something that already exists or is it a radical/disruptive idea?',
                 related_to=Project_PROFILE,
                 question_code="project_exists_or_radical"
                 ),
    structure_qs(qs_class='idea',
                 question_text=
                 "If your idea is the type that faces a chicken-and-egg problem in the sense that it won’t be attractive to users till it has a lot of users (e.g. a marketplace), how will you overcome that?"
                 ,
                 related_to=Project_PROFILE,
                 question_code='project_chicken-and-egg'
                 ),

    # traction

    structure_qs(qs_class='traction',
                 question_text="What steps have you taken to validate the market?",
                 related_to=Project_PROFILE,
                 question_code='project_validate_market'
                 ),

    structure_qs(qs_class='traction',
                 question_text="How many active customers/users have you?",
                 related_to=Project_PROFILE,
                 question_code='project_active_customer'
                 ),

    structure_qs(qs_class='traction',
                 question_text="Tell us more about these customers/users. Are they B2C/B2B customers? Revenue generating?",
                 related_to=Project_PROFILE,
                 question_code='project_more_about_customer'
                 ),
    structure_qs(qs_class='traction',
                 question_text="If you have already participated or committed to participate in an incubator, accelerator or pre-accelerator program, tell us about it.",
                 related_to=Project_PROFILE,
                 question_code='project_incubator_program_participate'
                 ),
    # Financials
    structure_qs(qs_class='financials',
                 question_text="Financial records if any.",
                 related_to=Project_PROFILE,
                 question_code='project_financial_record'
                 ),
    structure_qs(qs_class='financials',
                 question_text="Do you have revenue?",
                 related_to=Project_PROFILE,
                 question_code='project_have_revenue'
                 ),
    structure_qs(qs_class='financials',
                 question_text="What is your monthly growth rate?",
                 related_to=Project_PROFILE,
                 question_code='project_monthly_growth_rate'
                 ),
    structure_qs(qs_class='financials',
                 question_text="How do or will you make money? (SaaS model, Licensing, Consulting & Training etc).",
                 related_to=Project_PROFILE,
                 question_code='project_how_make_money'
                 ),
    structure_qs(qs_class='financials',
                 question_text="How much could you make? (We realize you can’t know precisely, but give your best estimate)",
                 related_to=Project_PROFILE,
                 question_code='project_make_money_estiamte'
                 ),
    structure_qs(qs_class='financials',
                 question_text="What are your monthly expenses for the next 12 months?",
                 related_to=Project_PROFILE,
                 question_code='project_year_expense'
                 ),
    structure_qs(qs_class='financials',
                 question_text="Have you successfully raised money before? If so, how much?",
                 related_to=Project_PROFILE,
                 question_code='project_successfully_raised_money_before'
                 ),
    # leagal
    structure_qs(qs_class='legal',
                 question_text="Are any of the founders covered by non-competes or intellectual property agreements that overlap with your project? If so, explain.",
                 related_to=Project_PROFILE,
                 question_code='project_intellectual_property_overlap_project'
                 ),
    structure_qs(qs_class='legal',
                 question_text="Was any of your code written by someone who is not one of your founders? If so, describe how can you legally use it. (Open source is ok of course).",
                 related_to=Project_PROFILE,
                 question_code='project_code_written_by_someone'
                 ),
    structure_qs(qs_class='legal',
                 question_text="Is there anything else we should know about your company? (co-founders who have left, etc)",
                 related_to=Project_PROFILE,
                 question_code='project_extra_info'
                 ),
    structure_qs(qs_class='legal',
                 question_text="Describe the equity ownership (ordinary, preferential shares) breakdown of your company between founders, employees, investors etc.",
                 related_to=Project_PROFILE,
                 question_code='project_equity_ownership_breakdown'
                 ),
    # others
    structure_qs(qs_class='other',
                 question_text="Why did you chose Early Bird Platform?",
                 related_to=Project_PROFILE,
                 question_code='project_why_chose_us'
                 ),
    structure_qs(qs_class='other',
                 question_text="Referred by?",
                 related_to=Project_PROFILE,
                 question_code='project_referred_by'
                 )

]
with transaction.atomic():
    for record in investment_qs:
        question_text = record.get('question_text'),
        question_hint = record.get('question_hint'),

        ans = [
            record.pop('ans1'),
            record.pop('ans2'),
            record.pop('ans3'),
            record.pop('ans4'),
            record.pop('ans5'),
        ]

        question_instance = Question.objects.create(**record)
        for item in ans:
            if item:
                q = QuestionDefaultAnswer.objects.create(question=question_instance, answer_text=item)
