# %%
import os

import django

os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'EarlyBird.settings.development')
os.environ['DJANGO_ALLOW_ASYNC_UNSAFE'] = 'true'
django.setup()
from apps.questionnaire.models import Question, QuestionDefaultAnswer
from django.db import transaction

# from eb_application.apps.questionnaire.models import Question, QuestionDefaultAnswer

INVESTMENT_PROFILE = 'investment_profile'
Company_PROFILE = 'company_profile'


def structure_qs(qs_class, question_text, question_code, hint=None, related_to=None,
                 widget_type=None,
                 ans1=None,
                 ans2=None,
                 ans3=None,
                 ans4=None,
                 ans5=None,
                 ans6=None,
                 ans7=None,
                 ans8=None,
                 ans9=None,
                 ans10=None,
                 ans11=None,
                 ans12=None,
                 ans13=None,
                 ):
    return {
        'widget_type': widget_type if widget_type else 'single_choice' if ans1 else 'input_text',
        'question_class': qs_class,
        'question_text': question_text,
        'question_hint': hint,
        'question_code': question_code,
        'related_to': related_to,
        'ans1': ans1,
        'ans2': ans2,
        'ans3': ans3,
        'ans4': ans4,
        'ans5': ans5,
        'ans6': ans6,
        'ans7': ans7,
        'ans8': ans8,
        'ans9': ans9,
        'ans10': ans10,
        'ans11': ans11,
        'ans12': ans12,
        'ans13': ans13,
    }


investment_qs = [

    structure_qs(qs_class='select areas of interest', question_text='What you would invest in?',
                 related_to=INVESTMENT_PROFILE, question_code='invest_invest_in'),
    structure_qs(qs_class='select areas of interest', question_text='What would you like to see more of in Vietnam? ',
                 related_to=INVESTMENT_PROFILE, question_code='invest_invest_context', widget_type='multiple_choice',
                 ans1='Technology',
                 ans2='Beauty',
                 ans3='Food & Beverage',
                 ans4='Education Agriculture',
                 ans5='Gaming',
                 ans6='Waist Management',
                 ans7='Renewal Energy',
                 ans8='Health & Wellness',
                 ans9='Real Estate',
                 ans10='Finance',
                 ans11='Hospitality',
                 ans12='Transportation',
                 ans13='Media'
                 ),

    structure_qs(qs_class='other information', question_text='Select your monthly income bracket?',
                 related_to=INVESTMENT_PROFILE, question_code='invest_income_bracket', widget_type='slider'),
    structure_qs(qs_class='other information', question_text='Select how much do you invest now??',
                 related_to=INVESTMENT_PROFILE, question_code='invest_invest_amount'),
    structure_qs(qs_class='other information',
                 question_text='Preferred Social Media platform to learn about new investment news?',
                 related_to=INVESTMENT_PROFILE, question_code='invest_learn_platform',
                 widget_type='multiple_choice',
                 ans1='facebook',
                 ans2='twitter',
                 ans3='instagram',
                 ),
    structure_qs(qs_class='other information',
                 question_text='Do you want to make passive income get a referral link and become an affiliate? ',
                 related_to=INVESTMENT_PROFILE, question_code='invest_referral_link'),

    structure_qs(qs_class='investor situation', question_text='How old are you?', related_to=INVESTMENT_PROFILE,
                 ans1='30 and under',
                 ans2='31-40',
                 ans3='41-55',
                 ans4='56 - 65',
                 ans5='Over 65',
                 question_code='invest_investor_age'),

    structure_qs(qs_class='investor situation',
                 question_text='What is your total annual income (i.e. employment, pension, rental property, investments, etc.)?',
                 hint="Your income level helps us determine your financial goals",
                 related_to=INVESTMENT_PROFILE,
                 ans1='Under $50,000',
                 ans2='$50,001  - $100,000',
                 ans3='$100,001 - $300,000',
                 ans4='Over $300,000',
                 question_code='invest_total_annual_income'
                 ),

    structure_qs(qs_class='investor situation',
                 question_text='How much of your monthly pay cheque do you put aside for savings and/or investments?',
                 related_to=INVESTMENT_PROFILE,
                 ans1='Greater than 12%',
                 ans2='6 - 12%',
                 ans3='1 - 5%',
                 ans4='I do not save',
                 question_code='invest_monthly_savings'
                 ),

    structure_qs(qs_class='investor situation',
                 question_text='How would you describe the security of your annual income, whether it is from employment or other sources?',
                 related_to=INVESTMENT_PROFILE,
                 ans1='very secure and stable',
                 ans2='Secure and stable',
                 ans3='Moderately secure and stable',
                 ans4='Somewhat insecure and unstable',
                 question_code='invest_annual_income_security'
                 ),

    structure_qs(qs_class='investment objectives and goals',
                 question_text='What is your main objective for this investment?',
                 related_to=INVESTMENT_PROFILE,
                 ans1='To maintain the value of your original investment',
                 ans2='Generate regular cash flow',
                 ans3='Grow your account and draw regular income from the account',
                 ans4='Grow your account',
                 ans5='Aggressively grow your account',
                 question_code='invest_invest_main_objective'
                 ),

    structure_qs(qs_class='investment objectives and goals',
                 hint='Hint: The length of time you invest will help us determine your ability to tolerate fluctuations in your account',
                 question_text='When do you expect to withdraw your money?',
                 related_to=INVESTMENT_PROFILE,
                 ans1='Within 3 years',
                 ans2='In 3 to 5 years',
                 ans3='In 5 to 10 years',
                 ans4='In 10 to 15 years',
                 ans5='In more than 15 years',
                 question_code='invest_withdraw_money'
                 ),

    structure_qs(qs_class='attitude towards risk',
                 question_text='If your investment dropped 25% in value, consistent with the market, how would you respond?',
                 related_to=INVESTMENT_PROFILE,
                 ans1='Cut your losses, sell your investments and hold cash with your entire account balance',
                 ans2='Sell half your investments and hold cash; keep remainder invested as is',
                 ans3='cut your losses, sell your investments and hold cash with your entire account balance',
                 ans4='Hold the portfolio and make no changes',
                 ans5='Take advantage of the lower price and invest more money',
                 question_code='invest_investment_dropped'
                 ),

    structure_qs(qs_class='attitude towards risk',
                 question_text='Which statement best describes your tolerance of market fluctuations?',
                 related_to=INVESTMENT_PROFILE,
                 ans1='Minor fluctuations are tolerable knowing you will likely get a lower return',
                 ans2='Some fluctuations in the value of your account are tolerable with a preference for a modest return',
                 ans3='Monthly fluctuations in the value of your account are tolerable with the possibility to earn a higher return',
                 ans4='You can tolerate daily fluctuations in the value of your account with the likelihood for even higher returns',
                 question_code='invest_market_tolerance'
                 ),

]
with transaction.atomic():
    for record in investment_qs:
        question_text = record.get('question_text'),
        question_hint = record.get('question_hint'),

        ans = [
            record.pop('ans1'),
            record.pop('ans2'),
            record.pop('ans3'),
            record.pop('ans4'),
            record.pop('ans5'),
            record.pop('ans6'),
            record.pop('ans7'),
            record.pop('ans8'),
            record.pop('ans9'),
            record.pop('ans10'),
            record.pop('ans11'),
            record.pop('ans12'),
            record.pop('ans13'),
        ]

        question_instance = Question.objects.create(**record)
        for item in ans:
            if item:
                q = QuestionDefaultAnswer.objects.create(question=question_instance, answer_text=item)
